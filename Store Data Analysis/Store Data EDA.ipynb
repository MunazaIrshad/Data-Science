# %% [markdown]
# **Objective:**
# Store owner wants to create an annual sales report for 2022.
# So that, store owner can understand their customers and grow
# more sales in 2023.
#
# Questions:
# 1) Compare the sale and orders using a single chart.
# 2) Which month got the highest sales and orders.
# 3) Who purchased more-men or women in 2022.
# 4) What are the different order status in 2022.
# 5) List top 10 states contributing to the sales.
# 6) Relation between age and gender based on number of orders.
# 7) Which channel is contributing to maximum sales.
# 8) Highest selling category?

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load/Read Data

Sales_Data = pd.read_excel('Store Data Analysis.xlsx')

# %%
# Show Data

Sales_Data.head()
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44     Adult 2022-12-04   Dec
# 1      2  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04   Dec
# 2      3  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04   Dec
# 3      4  404-7490807-6300351  7490807  Women   20  Teenager 2022-12-04   Dec
# 4      5  403-9293516-4577154  9293516  Women   62    Senior 2022-12-04   Dec
#
#       Status Channel   ... Category Size Qty  currency Amount  ship-city  \
# 0  Delivered   Myntra  ...    kurta  XXL   1       INR    376     MOHALI
# 1  Delivered     Ajio  ...      Set    L   1       INR   1449   GURUGRAM
# 2  Delivered   Myntra  ...      Set    S   1       INR    453    KOLKATA
# 3  Delivered   Amazon  ...      Set    M   1       INR    729  THANJAVUR
# 4  Delivered   Myntra  ...    kurta  XXL   1       INR    544   GURUGRAM
#
#     ship-state ship-postal-code  ship-country    B2B
# ...

# %%
# Data Information

Sales_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  object
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  object
#  4   Age               31047 non-null  int64
#  5   Age Group         31047 non-null  object
#  6   Date              31047 non-null  datetime64[ns]
#  7   Month             31047 non-null  object
#  8   Status            31047 non-null  object
#  9   Channel           31047 non-null  object
#  10  SKU               31047 non-null  object
#  11  Category          31047 non-null  object
#  12  Size              31047 non-null  object
#  13  Qty               31047 non-null  int64
#  14  currency          31047 non-null  object
#  15  Amount            31047 non-null  int64
# ...

# %%
# 1) Compare the sale and orders using a single chart.

sns.lineplot(Sales_Data, x ='Qty', y = 'Amount')
# Out:
# C:\Users\mnzir\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mnzir\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Qty', ylabel='Amount'>

# %%
sns.barplot(Sales_Data, x ='Qty', y = 'Amount')
# Out:
# <Axes: xlabel='Qty', ylabel='Amount'>

# %%
Sales_Data.columns
# Out:
# Index(['index', 'Order ID', 'Cust ID', 'Gender', 'Age', 'Age Group', 'Date',
#        'Month', 'Status', 'Channel ', 'SKU', 'Category', 'Size', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B'],
#       dtype='object')

# %%
# 2) Which month got the highest sales and order
# Highest number of Orders 

Sales_Data.groupby('Qty')['Month'].value_counts()
# Out:
# Qty  Month
# 1    Mar      2799
#      Feb      2732
#      Jan      2690
#      Apr      2671
#      Aug      2607
#      May      2597
#      Jun      2584
#      Jul      2569
#      Sep      2477
#      Oct      2413
#      Dec      2378
#      Nov      2374
# 2    Mar        17
#      May        17
#      Feb        16
#      Jun        11
#      Apr        10
#      Oct        10
#      Sep        10
#      Aug         9
#      Jan         9
#      Jul         8
#      Nov         7
#      Dec         6
# 3    Apr         3
#      Jan         3
#      Feb         2
#      Jun         2
#      Mar         2
#      May         2
#      Sep         2
#      Jul         1
#      Nov         1
#      Oct         1
# 4    Apr         1
#      Aug         1
#      Jul         1
#      Mar         1
#      May         1
#      Nov         1
# 5    Sep         1
# Name: count, dtype: int64

# %% [markdown]
# ### **March Has the highest number of Orders: 2799**

# %%
Sales_Data.groupby('Qty')['Month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Qty,Month'>

# %%
#Sales_Data.groupby('Qty')['Month'].value_counts().plot(kind='bar') 
sns.barplot(Sales_Data, x='Month', y='Qty')
# Out:
# <Axes: xlabel='Month', ylabel='Qty'>

# %%
# Highest Sales

Sales_Data.groupby('Month')['Amount'].sum()
# Out:
# Month
# Apr    1829263
# Aug    1808505
# Dec    1622033
# Feb    1875932
# Jan    1820601
# Jul    1772300
# Jun    1750966
# Mar    1928066
# May    1797822
# Nov    1615356
# Oct    1666662
# Sep    1688871
# Name: Amount, dtype: int64

# %% [markdown]
# ### **April has the Highest Sales: 1829263**

# %%
Sales_Data.groupby('Month')['Amount'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
sns.barplot(Sales_Data, x='Month', y='Amount')
# Out:
# <Axes: xlabel='Month', ylabel='Amount'>

# %%
# 3) Who purchased more-men or women in 2022.
gen_purch = Sales_Data.groupby('Gender')['Qty'].sum()
gen_purch
# Out:
# Gender
# Men       9535
# Women    21702
# Name: Qty, dtype: int64

# %% [markdown]
# ### **Womens purchased more : 21702 Orers**

# %%
# More Sale

gen_purch = Sales_Data.groupby('Gender')['Amount'].sum()
gen_purch
# Out:
# Gender
# Men       7613604
# Women    13562773
# Name: Amount, dtype: int64

# %% [markdown]
# ### **More Sales by women: 13562773**

# %%
# 4) What are the different order status in 2022.

Sales_Data['Status'].unique()
# Out:
# array(['Delivered', 'Refunded', 'Cancelled', 'Returned'], dtype=object)

# %%
Sales_Data['Status'].value_counts()
# Out:
# Status
# Delivered    28641
# Returned      1045
# Cancelled      844
# Refunded       517
# Name: count, dtype: int64

# %%
sns.countplot(Sales_Data, x = 'Status')
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
# 5) List top 10 states contributing to the sales.

Sales_Data.groupby('ship-state')['Amount'].sum().sort_values(ascending=False)
# Out:
# ship-state
# MAHARASHTRA           2990221
# KARNATAKA             2646358
# UTTAR PRADESH         2104659
# TELANGANA             1712439
# TAMIL NADU            1678877
# DELHI                 1248111
# KERALA                1008940
# WEST BENGAL            922444
# ANDHRA PRADESH         918499
# HARYANA                813320
# GUJARAT                715563
# MADHYA PRADESH         564026
# RAJASTHAN              547360
# BIHAR                  440051
# ODISHA                 414840
# PUNJAB                 361969
# UTTARAKHAND            327179
# ASSAM                  326423
# JHARKHAND              255054
# GOA                    180029
# CHHATTISGARH           174531
# JAMMU & KASHMIR        158736
# HIMACHAL PRADESH       146246
# MANIPUR                 78526
# CHANDIGARH              60726
# SIKKIM                  54181
# ANDAMAN & NICOBAR       51970
# PUDUCHERRY              48553
# NAGALAND                42846
# ARUNACHAL PRADESH       35003
# ...

# %%
Sales_Data.groupby('ship-state')['Amount'].sum().sort_values(ascending=False).head(10)
# Out:
# ship-state
# MAHARASHTRA       2990221
# KARNATAKA         2646358
# UTTAR PRADESH     2104659
# TELANGANA         1712439
# TAMIL NADU        1678877
# DELHI             1248111
# KERALA            1008940
# WEST BENGAL        922444
# ANDHRA PRADESH     918499
# HARYANA            813320
# Name: Amount, dtype: int64

# %%
Sales_Data.groupby('ship-state')['Amount'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='ship-state'>

# %%
# 6) Relation between age and gender based on number of orders.

Sales_Data.groupby(['Gender', 'Age Group'])['Qty'].sum()
# Out:
# Gender  Age Group
# Men     Adult         4819
#         Senior        1845
#         Teenager      2871
# Women   Adult        10812
#         Senior        4292
#         Teenager      6598
# Name: Qty, dtype: int64

# %%
Sales_Data.groupby(['Gender', 'Age Group'])['Qty'].count().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Gender,Age Group'>

# %%
# 7) Which channel is contributing to maximum sales.

Sales_Data.groupby('Channel ')['Amount'].sum()
# Out:
# Channel
# Ajio        1331427
# Amazon      7519933
# Flipkart    4573301
# Meesho       927606
# Myntra      4941540
# Nalli       1015329
# Others       867241
# Name: Amount, dtype: int64

# %%
Sales_Data.groupby('Channel ')['Amount'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Channel '>

# %% [markdown]
# ### **Amazon Contributing to maximum sales: 7519933**

# %%
# 8) Highest selling category?

Sales_Data.groupby('Category')['Amount'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### **Set is the highest selling category : 10507546**
